# %% [markdown]
# # Week 4 Day 3 - create_agent, the agent layer
#
# Yesterday you built a tool loop by hand in LangGraph: a chatbot node, a tools node, a conditional edge, and an edge back again. Today you get all of that from a single function call.
#
# `create_agent` is Layer 3. You hand it a model, some tools and a prompt, and it builds the agent loop for you. This is the next step along the control to convenience spine: you hand the loop to the framework and write far less code. The part that ties this whole week together is that what it builds is a LangGraph graph, the very kind you assembled by hand yesterday, and we will see that for ourselves once the agent has some tools.

# %%
# Imports and environment first, all in one place

from dotenv import load_dotenv
from IPython.display import Image, display
from pydantic import BaseModel, Field
from langchain.agents import create_agent
from langchain.agents.middleware import wrap_tool_call
from langchain_core.tools import tool
from langgraph.checkpoint.memory import MemorySaver
from langchain_mcp_adapters.client import MultiServerMCPClient

load_dotenv(override=True)
# Out:
# True

# %% [markdown]
# ## Part 1: the simplest agent
#
# An agent in its plainest form is a model with a prompt. We pass the model as a string in the form `provider:model`, and a system prompt to set its character.

# %%
from langchain_openai import ChatOpenAI

llm = ChatOpenAI(
        model="mistralai/mistral-nemotron",
    base_url="https://integrate.api.nvidia.com/v1",
    api_key=os.getenv("NVIDIA_API_KEY"),
)

agent = create_agent(
    model=llm,
    system_prompt="You are a helpful assistant who answers concisely.",
)

result = agent.invoke({"messages": [{"role": "user", "content": "What is the Model Context Protocol, in two sentences?"}]})
print(result["messages"][-1].content)
# Out:
# The **Model Context Protocol** is a standardized method for communication between large language models (LLMs) and other systems, ensuring clarity, structure, and consistency. It defines how inputs are framed with metadata like attribution, citations, tone, and structure, enabling better interpretability and compatibility.

# %% [markdown]
# ### And its async twin: ainvoke
#
# Everything in LangChain that can `invoke` can also `ainvoke`: same arguments, same result, awaited. You know asyncio well from earlier in the course, so there is nothing new to learn; this is simply the right way to call an agent from async code. It will matter at the end of this lab, where the browser tools only speak async.

# %%
result = await agent.ainvoke({"messages": [{"role": "user", "content": "In one sentence: why does async code suit agents so well?"}]})
print(result["messages"][-1].content)
# Out:
# Async code suits agents well because it enables non-blocking execution, allowing agents to efficiently handle multiple tasks or I/O operations concurrently without waiting for each one to complete.

# %% [markdown]
# ## Part 2: tools
#
# To make the agent useful, we give it tools. These are the same `@tool` functions from Day 1. We pass them in a list, and the agent runs the whole tool loop for us.

# %%
@tool
def get_weather(city: str) -> str:
    """Return today's weather for a city."""
    pretend = {"London": "rainy, 14 degrees", "Rome": "sunny, 27 degrees"}
    return pretend.get(city, "clear, 20 degrees")

@tool
def get_population(city: str) -> str:
    """Return the population of a city."""
    pretend = {"London": "8.9 million", "Rome": "2.8 million"}
    return pretend.get(city, "unknown")

agent = create_agent(
    model=llm,
    tools=[get_weather, get_population],
    system_prompt="You are a travel assistant. Use your tools to answer questions about cities.",
)

result = agent.invoke({"messages": [{"role": "user", "content": "What is the weather and population of Rome?"}]})
print(result["messages"][-1].content)
# Out:
# ---------------------------------------------------------------------------
# BadRequestError                           Traceback (most recent call last)
# Cell In[37], line 19
#      15     tools=[get_weather, get_population],
#      16     system_prompt="You are a travel assistant. Use your tools to answer questions about cities.",
#      17 )
#      18
# ---> 19 result = agent.invoke({"messages": [{"role": "user", "content": "What is the weather and population of Rome?"}]})
#      20 print(result["messages"][-1].content)
#
# File d:\Desktop\GIT-projects\Udemy-Agentic_AI_course\agents\.venv\Lib\site-packages\langgraph\pregel\main.py:3884, in Pregel.invoke(self, input, config, context, stream_mode, print_mode, output_keys, interrupt_before, interrupt_after, durability, control, version, **kwargs)
#    3881             chunks.append(chunk)
#    3882 else:
#    3883     # v1: collect interrupts from updates stream
# -> 3884     for chunk in self.stream(
#    3885         input,
#    3886         config,
#    3887         context=context,
#    3888         stream_mode=(
#    3889             ["updates", "values"] if stream_mode == "values" else stream_mode
#    3890         ),
#    3891         print_mode=print_mode,
#    3892         output_keys=output_keys,
#    3893         interrupt_before=interrupt_before,
#    3894         interrupt_after=interrupt_after,
#    3895         durability=durability,
#    3896         control=control,
#    3897         **kwargs,
#    3898     ):
#    3899         if stream_mode == "values":
#    3900             if len(chunk) == 2:
#
# File d:\Desktop\GIT-projects\Udemy-Agentic_AI_course\agents\.venv\Lib\site-packages\langgraph\pregel\main.py:2938, in Pregel.stream(self, input, config, context, stream_mode, print_mode, output_keys, interrupt_before, interrupt_after, durability, control, subgraphs, debug, version, **kwargs)
#    2936 for task in loop.match_cached_writes():
#    2937     loop.output_writes(task.id, task.writes, cached=True)
# -> 2938 for _ in runner.tick(
#    2939     [t for t in loop.tasks.values() if not t.writes],
#    2940     timeout=self.step_timeout,
#    2941     get_waiter=get_waiter,
#    2942     schedule_task=loop.accept_push,
#    2943 ):
#    2944     # emit output
#    2945     yield from _output(
#    2946         stream_mode,
#    2947         print_mode,
#    (...)   2953         _state_mapper,
#    2954     )
#    2955 loop.after_tick()
#
# File d:\Desktop\GIT-projects\Udemy-Agentic_AI_course\agents\.venv\Lib\site-packages\langgraph\pregel\_runner.py:207, in PregelRunner.tick(self, tasks, reraise, timeout, retry_policy, get_waiter, schedule_task)
#     205 scheduled_error_handler = False
#     206 try:
# --> 207     run_with_retry(
#     208         t,
#     209         retry_policy,
#     210         configurable={
#     211             CONFIG_KEY_CALL: partial(
#     212                 _call,
#     213                 weakref.ref(t),
#     214                 retry_policy=retry_policy,
#     215                 futures=weakref.ref(futures),
#     216                 schedule_task=schedule_task,
#     217                 submit=self.submit,
#     218             ),
#     219         },
#     220     )
#     221     self.commit(t, None)
#     222 except Exception as exc:
#
# File d:\Desktop\GIT-projects\Udemy-Agentic_AI_course\agents\.venv\Lib\site-packages\langgraph\pregel\_retry.py:617, in run_with_retry(task, retry_policy, configurable)
#     615     task.writes.clear()
#     616     # run the task
# --> 617     return task.proc.invoke(task.input, config)
#     618 except ParentCommand as exc:
#     619     ns: str = config[CONF][CONFIG_KEY_CHECKPOINT_NS]
#
# File d:\Desktop\GIT-projects\Udemy-Agentic_AI_course\agents\.venv\Lib\site-packages\langgraph\_internal\_runnable.py:684, in RunnableSeq.invoke(self, input, config, **kwargs)
#     682     # run in context
#     683     with set_config_context(config, run) as context:
# --> 684         input = context.run(step.invoke, input, config, **kwargs)
#     685 else:
#     686     input = step.invoke(input, config)
#
# File d:\Desktop\GIT-projects\Udemy-Agentic_AI_course\agents\.venv\Lib\site-packages\langgraph\_internal\_runnable.py:426, in RunnableCallable.invoke(self, input, config, **kwargs)
#     424         run_manager.on_chain_end(ret)
#     425 else:
# --> 426     ret = self.func(*args, **kwargs)
#     427 if self.recurse and isinstance(ret, Runnable):
#     428     return ret.invoke(input, config)
#
# File d:\Desktop\GIT-projects\Udemy-Agentic_AI_course\agents\.venv\Lib\site-packages\langchain\agents\factory.py:1331, in create_agent.<locals>.model_node(state, runtime)
#    1319 request = ModelRequest(
#    1320     model=model,
#    1321     tools=default_tools,
#    (...)   1327     runtime=runtime,
#    1328 )
#    1330 if wrap_model_call_handler is None:
# -> 1331     model_response = _execute_model_sync(request)
#    1332     return _build_commands(model_response)
#    1334 result = wrap_model_call_handler(request, _execute_model_sync)
#
# File d:\Desktop\GIT-projects\Udemy-Agentic_AI_course\agents\.venv\Lib\site-packages\langchain\agents\factory.py:1303, in create_agent.<locals>._execute_model_sync(request)
#    1300 if request.system_message:
#    1301     messages = [request.system_message, *messages]
# -> 1303 output = model_.invoke(messages)
#    1304 if name:
#    1305     output.name = name
#
# File d:\Desktop\GIT-projects\Udemy-Agentic_AI_course\agents\.venv\Lib\site-packages\langchain_core\runnables\base.py:5881, in RunnableBindingBase.invoke(self, input, config, **kwargs)
#    5874 @override
#    5875 def invoke(
#    5876     self,
#    (...)   5879     **kwargs: Any | None,
#    5880 ) -> Output:
# -> 5881     return self.bound.invoke(
#    5882         input,
#    5883         self._merge_configs(config),
#    5884         **{**self.kwargs, **kwargs},
#    5885     )
#
# File d:\Desktop\GIT-projects\Udemy-Agentic_AI_course\agents\.venv\Lib\site-packages\langchain_core\language_models\chat_models.py:474, in BaseChatModel.invoke(self, input, config, stop, **kwargs)
#     460 @override
#     461 def invoke(
#     462     self,
#    (...)    467     **kwargs: Any,
#     468 ) -> AIMessage:
#     469     config = ensure_config(config)
#     470     return cast(
#     471         "AIMessage",
#     472         cast(
#     473             "ChatGeneration",
# --> 474             self.generate_prompt(
#     475                 [self._convert_input(input)],
#     476                 stop=stop,
#     477                 callbacks=config.get("callbacks"),
#     478                 tags=config.get("tags"),
#     479                 metadata=config.get("metadata"),
#     480                 run_name=config.get("run_name"),
#     481                 run_id=config.pop("run_id", None),
#     482                 **kwargs,
#     483             ).generations[0][0],
#     484         ).message,
#     485     )
#
# File d:\Desktop\GIT-projects\Udemy-Agentic_AI_course\agents\.venv\Lib\site-packages\langchain_core\language_models\chat_models.py:1849, in BaseChatModel.generate_prompt(self, prompts, stop, callbacks, **kwargs)
#    1840 @override
#    1841 def generate_prompt(
#    1842     self,
#    (...)   1846     **kwargs: Any,
#    1847 ) -> LLMResult:
#    1848     prompt_messages = [p.to_messages() for p in prompts]
# -> 1849     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#
# File d:\Desktop\GIT-projects\Udemy-Agentic_AI_course\agents\.venv\Lib\site-packages\langchain_core\language_models\chat_models.py:1656, in BaseChatModel.generate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#    1653 for i, m in enumerate(input_messages):
#    1654     try:
#    1655         results.append(
# -> 1656             self._generate_with_cache(
#    1657                 m,
#    1658                 stop=stop,
#    1659                 run_manager=run_managers[i] if run_managers else None,
#    1660                 **kwargs,
#    1661             )
#    1662         )
#    1663     except BaseException as e:
#    1664         if run_managers:
#
# File d:\Desktop\GIT-projects\Udemy-Agentic_AI_course\agents\.venv\Lib\site-packages\langchain_core\language_models\chat_models.py:1996, in BaseChatModel._generate_with_cache(self, messages, stop, run_manager, **kwargs)
#    1994     result = generate_from_stream(iter(chunks))
#    1995 elif inspect.signature(self._generate).parameters.get("run_manager"):
# -> 1996     result = self._generate(
#    1997         messages, stop=stop, run_manager=run_manager, **kwargs
#    1998     )
#    1999 else:
#    2000     result = self._generate(messages, stop=stop, **kwargs)
#
# File d:\Desktop\GIT-projects\Udemy-Agentic_AI_course\agents\.venv\Lib\site-packages\langchain_openai\chat_models\base.py:1665, in BaseChatOpenAI._generate(self, messages, stop, run_manager, **kwargs)
#    1663         response = raw_response.parse()
#    1664 except openai.BadRequestError as e:
# -> 1665     _handle_openai_bad_request(e)
#    1666 except openai.APIError as e:
#    1667     _handle_openai_api_error(e)
#
# File d:\Desktop\GIT-projects\Udemy-Agentic_AI_course\agents\.venv\Lib\site-packages\langchain_openai\chat_models\base.py:1662, in BaseChatOpenAI._generate(self, messages, stop, run_manager, **kwargs)
#    1655         return _construct_lc_result_from_responses_api(
#    1656             response,
#    1657             schema=original_schema_obj,
#    1658             metadata=generation_info,
#    1659             output_version=self.output_version,
#    1660         )
#    1661     else:
# -> 1662         raw_response = self.client.with_raw_response.create(**payload)
#    1663         response = raw_response.parse()
#    1664 except openai.BadRequestError as e:
#
# File d:\Desktop\GIT-projects\Udemy-Agentic_AI_course\agents\.venv\Lib\site-packages\openai\_legacy_response.py:367, in to_raw_response_wrapper.<locals>.wrapped(*args, **kwargs)
#     363 extra_headers[RAW_RESPONSE_HEADER] = "true"
#     365 kwargs["extra_headers"] = extra_headers
# --> 367 return cast(LegacyAPIResponse[R], func(*args, **kwargs))
#
# File d:\Desktop\GIT-projects\Udemy-Agentic_AI_course\agents\.venv\Lib\site-packages\openai\_utils\_utils.py:298, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     296             msg = f"Missing required argument: {quote(missing[0])}"
#     297     raise TypeError(msg)
# --> 298 return func(*args, **kwargs)
#
# File d:\Desktop\GIT-projects\Udemy-Agentic_AI_course\agents\.venv\Lib\site-packages\openai\resources\chat\completions\completions.py:1212, in Completions.create(self, messages, model, audio, frequency_penalty, function_call, functions, logit_bias, logprobs, max_completion_tokens, max_tokens, metadata, modalities, n, parallel_tool_calls, prediction, presence_penalty, prompt_cache_key, prompt_cache_retention, reasoning_effort, response_format, safety_identifier, seed, service_tier, stop, store, stream, stream_options, temperature, tool_choice, tools, top_logprobs, top_p, user, verbosity, web_search_options, extra_headers, extra_query, extra_body, timeout)
#    1165 @required_args(["messages", "model"], ["messages", "model", "stream"])
#    1166 def create(
#    1167     self,
#    (...)   1209     timeout: float | httpx.Timeout | None | NotGiven = not_given,
#    1210 ) -> ChatCompletion | Stream[ChatCompletionChunk]:
#    1211     validate_response_format(response_format)
# -> 1212     return self._post(
#    1213         "/chat/completions",
#    1214         body=maybe_transform(
#    1215             {
#    1216                 "messages": messages,
#    1217                 "model": model,
#    1218                 "audio": audio,
#    1219                 "frequency_penalty": frequency_penalty,
#    1220                 "function_call": function_call,
#    1221                 "functions": functions,
#    1222                 "logit_bias": logit_bias,
#    1223                 "logprobs": logprobs,
#    1224                 "max_completion_tokens": max_completion_tokens,
#    1225                 "max_tokens": max_tokens,
#    1226                 "metadata": metadata,
#    1227                 "modalities": modalities,
#    1228                 "n": n,
#    1229                 "parallel_tool_calls": parallel_tool_calls,
#    1230                 "prediction": prediction,
#    1231                 "presence_penalty": presence_penalty,
#    1232                 "prompt_cache_key": prompt_cache_key,
#    1233                 "prompt_cache_retention": prompt_cache_retention,
#    1234                 "reasoning_effort": reasoning_effort,
#    1235                 "response_format": response_format,
#    1236                 "safety_identifier": safety_identifier,
#    1237                 "seed": seed,
#    1238                 "service_tier": service_tier,
#    1239                 "stop": stop,
#    1240                 "store": store,
#    1241                 "stream": stream,
#    1242                 "stream_options": stream_options,
#    1243                 "temperature": temperature,
#    1244                 "tool_choice": tool_choice,
#    1245                 "tools": tools,
#    1246                 "top_logprobs": top_logprobs,
#    1247                 "top_p": top_p,
#    1248                 "user": user,
#    1249                 "verbosity": verbosity,
#    1250                 "web_search_options": web_search_options,
#    1251             },
#    1252             completion_create_params.CompletionCreateParamsStreaming
#    1253             if stream
#    1254             else completion_create_params.CompletionCreateParamsNonStreaming,
#    1255         ),
#    1256         options=make_request_options(
#    1257             extra_headers=extra_headers,
#    1258             extra_query=extra_query,
#    1259             extra_body=extra_body,
#    1260             timeout=timeout,
#    1261             security={"bearer_auth": True},
#    1262         ),
#    1263         cast_to=ChatCompletion,
#    1264         stream=stream or False,
#    1265         stream_cls=Stream[ChatCompletionChunk],
#    1266     )
#
# File d:\Desktop\GIT-projects\Udemy-Agentic_AI_course\agents\.venv\Lib\site-packages\openai\_base_client.py:1332, in SyncAPIClient.post(self, path, cast_to, body, content, options, files, stream, stream_cls)
#    1323     warnings.warn(
#    1324         "Passing raw bytes as `body` is deprecated and will be removed in a future version. "
#    1325         "Please pass raw bytes via the `content` parameter instead.",
#    1326         DeprecationWarning,
#    1327         stacklevel=2,
#    1328     )
#    1329 opts = FinalRequestOptions.construct(
#    1330     method="post", url=path, json_data=body, content=content, files=to_httpx_files(files), **options
#    1331 )
# -> 1332 return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File d:\Desktop\GIT-projects\Udemy-Agentic_AI_course\agents\.venv\Lib\site-packages\openai\_base_client.py:1105, in SyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#    1102             err.response.read()
#    1104         log.debug("Re-raising status error")
# -> 1105         raise self._make_status_error_from_response(err.response) from None
#    1107     break
#    1109 assert response is not None, "could not resolve response (should never happen)"
#
# BadRequestError: Error code: 400 - {'object': 'error', 'message': ' Assistant message must have either content or tool_calls, but not both.', 'type': 'BadRequestError', 'param': None, 'code': 400}
# During task with name 'model' and id '2299a942-0072-7276-7a54-7b73fccfc078'

# %% [markdown]
# ## The reveal: it is a LangGraph graph
#
# Now that our agent has tools, let us draw it. Because `create_agent` returns a compiled LangGraph graph, we can render it with exactly the same call we used yesterday. Look at the shape: a model node, a tools node, and the conditional loop between them. This is the graph you built by hand on Day 2, handed to you in one line.

# %%
display(Image(agent.get_graph().draw_mermaid_png()))

# %% [markdown]
# ## Part 3: memory
#
# By default each call to `invoke` is a fresh start. To remember a conversation we give the agent a checkpointer, exactly as we did with the graph yesterday, and pass a `thread_id` so it knows which conversation we mean.

# %%
memory_agent = create_agent(
    model=llm,
    tools=[get_weather],
    checkpointer=MemorySaver(),
)

config = {"configurable": {"thread_id": "trip-planning"}}
memory_agent.invoke({"messages": [{"role": "user", "content": "I am planning a trip to London."}]}, config=config)
result = memory_agent.invoke({"messages": [{"role": "user", "content": "What is the weather like where I am going on my trip?"}]}, config=config)
print(result["messages"][-1].content)
# Out:
# To provide you with the weather information for your trip destination, I need to know the specific location you're traveling to. Could you please specify the city or region you'll be visiting?

# %% [markdown]
# ## Part 4: structured output
#
# When you want a typed object back rather than prose, pass a Pydantic model as `response_format`. The agent still does its work and uses its tools, then fills in your object. You read it from the `structured_response` key.

# %%
class CityReport(BaseModel):
    city: str = Field(description="The city name")
    weather: str = Field(description="A short weather description")
    population: str = Field(description="The population")

report_agent = create_agent(
    model=llm,
    tools=[get_weather, get_population],
    response_format=CityReport,
)

result = report_agent.invoke({"messages": [{"role": "user", "content": "Give me a report on London."}]})
report = result["structured_response"]
print(report)
print("Just the weather:", report.weather)
# Out:
# city='London' weather='Rainy, 14 degrees' population='8.9 million'
# Just the weather: Rainy, 14 degrees

# %% [markdown]
# ## Part 5: middleware
#
# Middleware is a powerful feature to shape an agent's behavior. It lets you run your own code at fixed points in the loop: before the model is called, after it answers, or around each tool call.
#
# Here is a small piece of custom middleware that prints every tool call as it happens, so you can watch the agent at work. The `@wrap_tool_call` decorator wraps each tool call: we log it, then call `handler` to let it proceed.

# %%
@wrap_tool_call
def log_tool_calls(request, handler):
    call = request.tool_call
    print(f"  [middleware] calling {call['name']} with {call['args']}")
    return handler(request)

watched_agent = create_agent(
    model=llm,
    tools=[get_weather, get_population],
    system_prompt="You are a travel assistant. Use your tools.",
    middleware=[log_tool_calls],
)

result = watched_agent.invoke({"messages": [{"role": "user", "content": "Weather and population of London and Rome?"}]})
print("\nFinal answer:", result["messages"][-1].content)
# Out:
# Final answer: Let me get the weather and population for you.
#
# get_weather(city="London")
#
# get_weather(city="Rome")
#
# get_population(city="London")
#
# get_population(city="Rome")

# %% [markdown]
# LangChain also ships a range of ready made middleware, including `SummarizationMiddleware` to keep long conversations within the context window, `PIIMiddleware` to redact sensitive data, retry and call-limit middleware, and `HumanInTheLoopMiddleware` to pause for human approval.

# %% [markdown]
# ## Before Part 6: Node and Playwright
#
# The last part of this lab uses tools that live in a separate program, an MCP server, and that program runs on Node. Two quick checks before we start.
#
# First, Node itself; you want v22 or later. If the cell below fails, install Node with one command:
#
# - **Windows**, in PowerShell: `winget install OpenJS.NodeJS.LTS`
# - **Mac**, in Terminal: `brew install node`
# - **Linux**, or if neither works for you: see the guide at [setup/SETUP-node.md](../setup/SETUP-node.md)
#
# After installing, quit Cursor completely and start it again, then reopen this notebook and re-run the lab from the top. That full restart matters: a freshly installed Node is invisible to a notebook that was already running, and restarting just the kernel is not enough.

# %%
# !node --version
# !npx --version
# Out:
# v24.12.0
# 11.6.2

# %% [markdown]
# Second, Playwright, Microsoft's browser automation framework. There is nothing to install: `npx` fetches it on demand, and it drives the copy of Chrome already on your machine. Chrome does not need to be running; Playwright launches its own.
#
# The cell below proves the whole chain with no AI involved at all: Node runs Playwright, Playwright opens Chrome, loads Hacker News, and saves a screenshot. The first run takes a little longer while npx downloads the package.
#
# If it complains that Chrome is not found, either install Chrome normally or run `npx playwright install chrome` in a terminal, then try again.

# %%
# !npx -y playwright@latest screenshot --channel=chrome https://news.ycombinator.com playwright_check.png
display(Image("playwright_check.png"))
# Out:
# Navigating to https://news.ycombinator.com
# Capturing screenshot into playwright_check.png

# %% [markdown]
# ## Part 6: an MCP server, and a real browser
#
# Tools do not have to be Python functions you write. The Model Context Protocol is a standard way for agents to use tools that live in a separate server. LangChain loads those tools with `langchain-mcp-adapters`, and from the agent's point of view they are just tools like any other.
#
# We will connect to Microsoft's Playwright MCP server, which drives the same real browser you just smoke-tested. It runs headed by default, so you can watch it work; on a Linux box with no display it quietly falls back to headless. Because these tools talk to a separate process, they are async, so we load them with `await` and run the agent with `ainvoke`, which you met in Part 1.

# %% [markdown]
# ### One adjustment for Windows
#
# When Python launches another program, it hands that program a place to write its error messages. Inside a Jupyter notebook on Windows, that place is not a real file, and the library that launches MCP servers trips over it (a known issue in the MCP Python SDK, which only shows up in notebooks, never in ordinary Python scripts). The cell below points the MCP server's error log somewhere safe before we connect. On Mac and Linux it does nothing at all, so run it either way and carry on.

# %%
import sys

if sys.platform == "win32":
    import subprocess
    from functools import partial
    import langchain_mcp_adapters.sessions as mcp_sessions

    mcp_sessions.stdio_client = partial(mcp_sessions.stdio_client, errlog=subprocess.DEVNULL)
    print("Applied the Windows adjustment")
else:
    print("Not Windows, so nothing to do here")
# Out:
# Applied the Windows adjustment

# %%
client = MultiServerMCPClient({
    "playwright": {
        "transport": "stdio",
        "command": "npx",
        "args": ["-y", "@playwright/mcp@latest", "--isolated"],
    }
})

browser_tools = await client.get_tools()
print(f"Loaded {len(browser_tools)} browser tools:")
for t in browser_tools:
    print(" -", t.name)
# Out:
# Loaded 24 browser tools:
#  - browser_close
#  - browser_resize
#  - browser_console_messages
#  - browser_handle_dialog
#  - browser_evaluate
#  - browser_file_upload
#  - browser_drop
#  - browser_find
#  - browser_fill_form
#  - browser_press_key
#  - browser_type
#  - browser_navigate
#  - browser_navigate_back
#  - browser_network_requests
#  - browser_network_request
#  - browser_run_code_unsafe
#  - browser_take_screenshot
#  - browser_snapshot
#  - browser_click
#  - browser_drag
#  - browser_hover
#  - browser_select_option
#  - browser_tabs
#  - browser_wait_for

# %% [markdown]
# Now we hand those browser tools to an ordinary `create_agent` and ask it to visit Hacker News and report what it finds. Watch the browser window open and navigate on its own.

# %%
browser_agent = create_agent(
    model=llm,
    tools=browser_tools,
    system_prompt="You are a web research assistant. Use the browser tools to complete the task, then report clearly.",
)

result = await browser_agent.ainvoke({"messages": [{"role": "user",
    "content": "Go to https://news.ycombinator.com and tell me the titles of the top three stories on the front page."}]})
print(result["messages"][-1].content)
# Out:
# Finding titles of the top three stories on the front page...
#
# 1. title: **AI-Powered Hiring Tools for Startup Recruitment**
# 2. title: **AI Is Poised to Revolutionize School Science Labs**
# 3. title: **Europe’s First Carbon-Neutral Country**
#    ```js
#    [
#       {
#          "box": "556,11,29.990625,18",
#          "children": [],
#          "role": "text",
#          "text": "2 points by KTK6129 hours ago |"
#       },
#       {
#          "box": "610,11,14,15",
#          "children": [],
#          "role": "link",
#          "text": "hide"
#       },
#       {
#          "box": "151,37,15,15",
#          "children": [
#             {
#                "box": "151,37,15,15",
#                "children": [
#                   {
#                      "box": "154,40,16,8",
#                      "children": [],
#                      "role": "text",
#                      "text": "flag"
#                   }
#                ],
#                "role": "generic",
#                "text": "flag"
#             },
#             {
#                "box": "166,37,15,15",
#                "children": [],
#                "role": "separator",
#                "text": " "
#             }
#          ],
#          "role": "generic",
#          "text": "flag "
#       }
#    ]
#    [...]
#    ```
#  Use  `browser_evaluate` for JavaScript execution and return the information that you want to retrieve from the webpage."

# %%
result = await browser_agent.ainvoke({
    "messages": [{
        "role": "user",
        "content": (
            "1. Navigate to https://news.ycombinator.com using `browser_navigate`.\n"
            "2. Use `browser_snapshot` to capture the page content.\n"
            "3. Look strictly inside the `.titleline` elements in the snapshot text.\n"
            "4. Output the exact real text of the first 3 story titles verbatim—do not invent or guess any titles."
        )
    }]
})
print(result["messages"][-1].content)
# Out:
# I don't see any story titles held strictly within the `.titleline` elements from the snapshot text. Could you check if the page content loaded correctly or if there might be an issue with the search parameters?

# %%
eval_tool = next(t for t in browser_tools if t.name == "browser_evaluate")
result = await eval_tool.ainvoke({
    "function": "() => Array.from(document.querySelectorAll('.titleline > a')).slice(0, 3).map(el => el.textContent.trim())"
})
print("Top 3 Stories:", result)
# Out:
# Top 3 Stories: [{'type': 'text', 'text': "### Result\n[]\n### Ran Playwright code\n```js\nawait page.evaluate('() => Array.from(document.querySelectorAll(\\'.titleline > a\\')).slice(0, 3).map(el => el.textContent.trim())');\n```\n### Page\n- Page URL: about:blank", 'id': 'lc_0e6e6736-3013-4c63-89c6-561c8d16c930'}]

# %% [markdown]
# ## Recap, and where we are heading
#
# In one lab you have built an agent in a single line, seen that it is really a LangGraph graph, given it tools, memory and structured output, shaped it with middleware, and let it drive a real browser through an MCP server. This is the layer you will reach for most often in your own work.
#
# Tomorrow we go one layer higher. Deep Agents take create_agent and wrap it in a full harness for work that takes many steps.

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/exercise.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Exercise</h2>
#             <span style="color:#ff7800;">Give the browser agent a checkpointer and a thread_id, then hold a short back and forth with it: ask it to open a site, then ask a follow up question about what it found, and confirm it remembers. For a bigger challenge, write a piece of middleware that refuses any navigation to a site you put on a block list, and prove it works.
#             </span>
#         </td>
#     </tr>
# </table>
